# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_parquet("flights_clean_1gb")

# %%
size_mb = data.memory_usage(deep=True, index=True).sum() / 1024 ** 2
print(f"Data size: {size_mb:.2f} MB")
# Out:
# Data size: 940.81 MB

# %%
data.columns
# Out:
# Index(['legId', 'searchDate', 'flightDate', 'startingAirport',
#        'destinationAirport', 'numStops', 'layoverDurationMinutes',
#        'totalTravelDistance', 'travelDurationMinutes', 'seatsRemaining',
#        'isBasicEconomy', 'isRefundable', 'isNonStop', 'fareBasisCode',
#        'baseFare', 'totalFare', 'segmentsDepartureTime', 'segmentsArrivalTime',
#        'segmentsArrivalAirportCodes', 'segmentsDepartureAirportCodes',
#        'segmentsAirlineNames', 'segmentsAirlineCodes', 'segmentAircraft',
#        'segmentsDurationSeconds', 'segmentsDistances', 'segmentsCabinCodes'],
#       dtype='str')

# %%
from pandas import to_datetime as datetime

data['segmentsDepartureTime'] = data['segmentsDepartureTime'].apply(lambda x: list(x.to_pydatetime()))
data['segmentsArrivalTime'] = data['segmentsArrivalTime'].apply(lambda x: list(x.to_pydatetime()))

# %%
type(data.segmentsArrivalTime.iat[0][0])
# Out:
# datetime.datetime

# %%
data.to_parquet("flights_1gb.parquet")

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(data.index, data.totalFare)
plt.show()
